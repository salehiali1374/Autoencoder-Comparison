# %% [markdown]
# Lets first import CIFAR-10 Dataset and see what's going on!

# %%
from matplotlib import pyplot
from keras.datasets import cifar10

(trainX, trainY), (testX, testY) = cifar10.load_data()

print('Train: X=%s, y=%s' % (trainX.shape, trainY.shape))
print('Test: X=%s, y=%s' % (testX.shape, testY.shape))


for i in range(9):
    pyplot.subplot(330 + 1 + i)
    pyplot.imshow(trainX[i])
pyplot.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
input_shape = (32,32,3)
output_shape = 10

# %% [markdown]
# One-Hot Encoding the Target Value

# %%
from keras.utils.np_utils import to_categorical

trainY = to_categorical(trainY)
testY = to_categorical(testY)

# %% [markdown]
# Prepare and Normalize Data

# %%
trainX = trainX.astype('float32')
testX = testX.astype('float32')

trainX = trainX / 255.0
testX = testX / 255.0

# %% [markdown]
# Defining The Convlutional Supervised Autoencoder

# %%
from keras.layers import Conv2D, Dense, Input, MaxPooling2D, UpSampling2D, Flatten
from keras import models
from keras.layers.merge import Concatenate

input_img = Input(shape=input_shape)

encode1 = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
encode2 = Conv2D(64, (3, 3), activation='relu', padding='same')(encode1)
encode3 = MaxPooling2D((2, 2), padding='same')(encode2)
encode4 = Conv2D(32, (3, 3), activation='relu', padding='same')(encode3)
bottleneck = MaxPooling2D((2, 2), padding='same')(encode4)

decode1 = Conv2D(32, (3, 3), activation='relu', padding='same')(bottleneck)
decode2 = UpSampling2D((2, 2))(decode1)
decode3 = Conv2D(64, (3, 3), activation='relu', padding='same')(decode2)
decode4 = UpSampling2D((2, 2))(decode3)
decode5 = Conv2D(128, (3, 3), activation='relu', padding='same')(decode4)
decode6 = Conv2D(3, (3, 3), activation='relu', padding='same')(decode5)

cae = models.Model(input_img, decode6)

cae.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        73792
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 32)          9248
#
#  up_sampling2d (UpSampling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        18496
#
#  up_sampling2d_1 (UpSampling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 128)       73856
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 3)         3459
#
# =================================================================
# Total params: 200,899
# Trainable params: 200,899
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Optimizer Settings

# %%
from tensorflow.keras import optimizers
from keras.losses import huber, MSE

learning_rate = 1E-3 # to be tuned!

cae.compile(loss=MSE, optimizer=optimizers.Adam(lr=learning_rate),metrics=['acc'])
# Out:
# c:\users\mesto\appdata\local\programs\python\python39\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# Training The Model

# %%
history = cae.fit(trainX, trainX, 
                   batch_size=64, 
                   epochs=50, 
                   validation_split=0.1)
# Out:
# Epoch 1/50
# 704/704 [==============================] - 19s 23ms/step - loss: 0.0091 - acc: 0.6921 - val_loss: 0.0041 - val_acc: 0.7862
# Epoch 2/50
# 704/704 [==============================] - 16s 22ms/step - loss: 0.0038 - acc: 0.7883 - val_loss: 0.0031 - val_acc: 0.8139
# Epoch 3/50
# 704/704 [==============================] - 16s 22ms/step - loss: 0.0031 - acc: 0.8037 - val_loss: 0.0027 - val_acc: 0.8047
# Epoch 4/50
# 704/704 [==============================] - 16s 23ms/step - loss: 0.0028 - acc: 0.8075 - val_loss: 0.0027 - val_acc: 0.7955
# Epoch 5/50
# 704/704 [==============================] - 16s 22ms/step - loss: 0.0026 - acc: 0.8087 - val_loss: 0.0022 - val_acc: 0.8270
# Epoch 6/50
# 704/704 [==============================] - 16s 23ms/step - loss: 0.0024 - acc: 0.8136 - val_loss: 0.0022 - val_acc: 0.8299
# Epoch 7/50
# 704/704 [==============================] - 16s 23ms/step - loss: 0.0021 - acc: 0.8205 - val_loss: 0.0023 - val_acc: 0.8340
# Epoch 8/50
# 704/704 [==============================] - 16s 23ms/step - loss: 0.0020 - acc: 0.8203 - val_loss: 0.0019 - val_acc: 0.8232
# Epoch 9/50
# 704/704 [==============================] - 16s 23ms/step - loss: 0.0019 - acc: 0.8235 - val_loss: 0.0018 - val_acc: 0.8401
# Epoch 10/50
# 704/704 [==============================] - 16s 23ms/step - loss: 0.
50
# 704/704 [==============================] - 16s 23ms/step - loss: 0.0010 - acc: 0.8527 - val_loss: 9.9930e-04 - val_acc: 0.8371
# Epoch 47/50
# 704/704 [==============================] - 16s 23ms/step - loss: 0.0010 - acc: 0.8526 - val_loss: 9.9041e-04 - val_acc: 0.8603
# Epoch 48/50
# 704/704 [==============================] - 16s 23ms/step - loss: 9.9306e-04 - acc: 0.8543 - val_loss: 0.0010 - val_acc: 0.8543
# Epoch 49/50
# 704/704 [==============================] - 16s 23ms/step - loss: 9.9407e-04 - acc: 0.8537 - val_loss: 9.3711e-04 - val_acc: 0.8417
# Epoch 50/50
# 704/704 [==============================] - 16s 23ms/step - loss: 9.8090e-04 - acc: 0.8546 - val_loss: 9.4809e-04 - val_acc: 0.8515

# %% [markdown]
# Plotting the results

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Using the encoder for fine-tuning

# %%
sae_encoder = models.Model(input_img, bottleneck)
sae_encoder.summary()

bottle_neck_train = sae_encoder.predict(trainX)
bottle_neck_test = sae_encoder.predict(testX)

print('bottle_neck_train:{}'.format(bottle_neck_train.shape))
print('bottle_neck_test:{}'.format(bottle_neck_test.shape))
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        73792
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
# =================================================================
# Total params: 95,840
# Trainable params: 95,840
# Non-trainable params: 0
# _________________________________________________________________
# bottle_neck_train:(50000, 8, 8, 32)
# bottle_neck_test:(10000, 8, 8, 32)

# %% [markdown]
# Build Classifier for fine-tune

# %%
input_feat = Input(shape=(8,8,32))

hidden0 = Flatten()(input_feat)
hidden1 = Dense(128, activation='relu')(hidden0)
output = Dense(output_shape, activation='softmax')(hidden1)

classifier = models.Model(input_feat, output)

classifier.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 8, 8, 32)]        0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 128)               262272
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 263,562
# Trainable params: 263,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(loss='categorical_crossentropy',optimizer=optimizers.RMSprop(lr=learning_rate),metrics=['acc'])

history = classifier.fit(bottle_neck_train, trainY, 
                        batch_size=64, 
                        epochs=50, 
                        validation_split=0.1)
# Out:
# Epoch 1/50
# 704/704 [==============================] - 3s 3ms/step - loss: 1.6680 - acc: 0.3977 - val_loss: 1.8111 - val_acc: 0.3318
# Epoch 2/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.4206 - acc: 0.4972 - val_loss: 1.6197 - val_acc: 0.4246
# Epoch 3/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.3365 - acc: 0.5292 - val_loss: 1.5076 - val_acc: 0.4594
# Epoch 4/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.2769 - acc: 0.5495 - val_loss: 1.5433 - val_acc: 0.4672
# Epoch 5/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.2341 - acc: 0.5653 - val_loss: 1.5780 - val_acc: 0.4664
# Epoch 6/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.1956 - acc: 0.5779 - val_loss: 1.6539 - val_acc: 0.4434
# Epoch 7/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.1682 - acc: 0.5889 - val_loss: 1.4177 - val_acc: 0.4948
# Epoch 8/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.1419 - acc: 0.5981 - val_loss: 1.3853 - val_acc: 0.5238
# Epoch 9/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.1196 - acc: 0.6058 - val_loss: 1.2347 - val_acc: 0.5652
# Epoch 10/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.0996 - acc: 0.6119 - val_loss: 1.2640 - val_acc: 0.5750
# Epoch 11/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.0826 - acc: 0.6217 - val_loss: 1.7935 - val_acc: 0.4330
# Epoch 12/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.0638 - acc: 0.6242 - val_loss: 1.3678 - val_acc: 0.5198
# Epoch 13/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.0522 - acc: 0.6308 - val_loss: 1.3691 - val_acc: 0.5312
# Epoch 14/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.0329 - acc: 0.6375 - val_loss: 1.5677 - val_acc: 0.4870
# Epoch 15/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.0214 - acc: 0.6426 - val_loss: 1.8547 - val_acc: 0.4302
# Epoch 16/50
# 704/704 [==============================] - 2s 3ms/step - loss: 1.0170 - acc: 0.6436 - val_loss: 1.4495 - val_acc: 0.5154
# Epoch 17/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9989 - acc: 0.6496 - val_loss: 1.2441 - val_acc: 0.5628
# Epoch 18/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9866 - acc: 0.6532 - val_loss: 1.3661 - val_acc: 0.5526
# Epoch 19/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9795 - acc: 0.6571 - val_loss: 1.2334 - val_acc: 0.5756
# Epoch 20/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9674 - acc: 0.6605 - val_loss: 1.4240 - val_acc: 0.5072
# Epoch 21/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9583 - acc: 0.6643 - val_loss: 1.4613 - val_acc: 0.5056
# Epoch 22/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9476 - acc: 0.6670 - val_loss: 1.3426 - val_acc: 0.5508
# Epoch 23/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9415 - acc: 0.6697 - val_loss: 1.5549 - val_acc: 0.4816
# Epoch 24/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9308 - acc: 0.6729 - val_loss: 1.5410 - val_acc: 0.5240
# Epoch 25/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9252 - acc: 0.6749 - val_loss: 1.6120 - val_acc: 0.4984
# Epoch 26/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9155 - acc: 0.6803 - val_loss: 1.3533 - val_acc: 0.5736
# Epoch 27/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9080 - acc: 0.6796 - val_loss: 1.3186 - val_acc: 0.5628
# Epoch 28/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9002 - acc: 0.6857 - val_loss: 1.1992 - val_acc: 0.5954
# Epoch 29/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8932 - acc: 0.6852 - val_loss: 1.2392 - val_acc: 0.5882
# Epoch 30/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8883 - acc: 0.6874 - val_loss: 1.1158 - val_acc: 0.6226
# Epoch 31/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8790 - acc: 0.6905 - val_loss: 1.2956 - val_acc: 0.5662
# Epoch 32/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8751 - acc: 0.6936 - val_loss: 1.2412 - val_acc: 0.5938
# Epoch 33/50
# 704/704 [==============================] - 2s 4ms/step - loss: 0.8679 - acc: 0.6938 - val_loss: 1.5874 - val_acc: 0.5122
# Epoch 34/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8618 - acc: 0.6987 - val_loss: 1.4510 - val_acc: 0.5460
# Epoch 35/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8569 - acc: 0.6972 - val_loss: 1.2056 - val_acc: 0.5994
# Epoch 36/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8495 - acc: 0.7017 - val_loss: 1.3665 - val_acc: 0.5544
# Epoch 37/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8450 - acc: 0.7041 - val_loss: 1.3917 - val_acc: 0.5692
# Epoch 38/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8412 - acc: 0.7035 - val_loss: 1.3032 - val_acc: 0.5884
# Epoch 39/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8367 - acc: 0.7055 - val_loss: 1.1023 - val_acc: 0.6382
# Epoch 40/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8293 - acc: 0.7068 - val_loss: 1.6095 - val_acc: 0.5150
# Epoch 41/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8212 - acc: 0.7107 - val_loss: 1.3307 - val_acc: 0.5708
# Epoch 42/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8165 - acc: 0.7109 - val_loss: 1.2944 - val_acc: 0.5936
# Epoch 43/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8110 - acc: 0.7134 - val_loss: 1.2575 - val_acc: 0.6010
# Epoch 44/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8100 - acc: 0.7140 - val_loss: 1.4595 - val_acc: 0.5500
# Epoch 45/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8042 - acc: 0.7170 - val_loss: 1.1410 - val_acc: 0.6294
# Epoch 46/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.7955 - acc: 0.7186 - val_loss: 1.2383 - val_acc: 0.6124
# Epoch 47/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.7970 - acc: 0.7194 - val_loss: 1.4755 - val_acc: 0.5554
# Epoch 48/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.7893 - acc: 0.7206 - val_loss: 1.2124 - val_acc: 0.6054
# Epoch 49/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.7859 - acc: 0.7227 - val_loss: 1.2718 - val_acc: 0.5976
# Epoch 50/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.7788 - acc: 0.7247 - val_loss: 1.3517 - val_acc: 0.5768

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
bottle_neck_test = sae_encoder.predict(testX)
score = classifier.evaluate(bottle_neck_test, testY, verbose=0)
print('e = {} , acc = {}'.format(score[0], score[1]))
# Out:
# e = 1.3712152242660522 , acc = 0.5758000016212463
